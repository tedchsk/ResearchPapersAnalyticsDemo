# %% [markdown]
# <h2>Word2Vec on Research papers</h2>
# <p>In this notebook, we will see how word2vec perform in research papers.</p>
# <p>Word2Vec tries to create a vector for each word. And we want two vector to be close to each other if they have similar semantics.</p>

# %%
# -*- coding: utf-8 -*-
#Import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import codecs
import re
import os
from bs4 import BeautifulSoup # $ pip install beautifulsoup4
from wordcloud import WordCloud
# %matplotlib inline

# %%
cleaned_paper_df = pd.read_csv('../dataset/cleaned_papers_pdf.csv',encoding='utf-8')

# %%
print(cleaned_paper_df.shape)
cleaned_paper_df.head(10)
# Out:
# (784, 5)
#                    name                                            content  \
# 0  Banlue Srisuchinwong  Thammasat Int. J. Sc. Tech., Vol.6, No.l, Janu...
# 1  Banlue Srisuchinwong  ___________________________________________0-7...
# 2  Banlue Srisuchinwong  This paper is a postprint of a paper submitted...
# 3  Banlue Srisuchinwong  Electronic version of an article published as ...
# 4  Banlue Srisuchinwong  PhysicsLettersA373(2009)4038–4043 Contentslist...
# 5  Banlue Srisuchinwong  41UTCC Engineering Research Papers 2008A Low-P...
# 6  Banlue Srisuchinwong  1Improved Implementation of Sprott™s Chaotic O...
# 7  Banlue Srisuchinwong  Compound Structures of Six New Chaotic Attract...
# 8  Banlue Srisuchinwong  Int.J.Electron.Commun.(AEÜ)61(2007)307–313 www...
# 9  Banlue Srisuchinwong  International Journal of Engineering Research ...
#
#                                            directory isValid        faculty
# 0  ../papers/ICT_professor/Banlue Srisuchinwong/1...    True  ICT_professor
# 1  ../papers/ICT_professor/Banlue Srisuchinwong/1...    True  ICT_professor
# 2  ../papers/ICT_professor/Banlue Srisuchinwong/2...    True  ICT_professor
# 3  ../papers/ICT_professor/Banlue Srisuchinwong/2...    True  ICT_professor
# 4  ../papers/ICT_professor/Banlue Srisuchinwong/2...    True  ICT_professor
# 5  ../papers/ICT_professor/Banlue Srisuchinwong/4...    True  ICT_professor
# 6  ../papers/ICT_professor/Banlue Srisuchinwong/4...    True  ICT_professor
# 7  ../papers/ICT_professor/Banlue Srisuchinwong/5...    True  ICT_professor
# 8  ../papers/ICT_professor/Banlue Srisuchinwong/8...    True  ICT_professor
# 9  ../papers/ICT_professor/Banlue Srisuchinwong/a...    True  ICT_professor

# %%
# Import various modules for string cleaning
from nltk.corpus import stopwords

def review_to_wordlist( paper_content ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", paper_content) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))      
    stops.add('cid')
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops] 
    
    # 5. Cut word with only 1 character except a,i,u
  
    meaningful_words = [w for w in meaningful_words if len(w)!=1 or w in['a','i','u']]
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
# Download the punkt tokenizer for sentence splitting  
import nltk
# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

from nltk.corpus import stopwords # Import the stop word list
# Define a function to split a review into parsed sentences
def paper_to_sentences( review, tokenizer, remove_stopwords=False ):
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set")
for paper in cleaned_paper_df["content"]:
    sentences += paper_to_sentences(paper, tokenizer)
print("Finished parsing")
# Out:
# Parsing sentences from training set
# Finished parsing

# %%
split_sentences = [sentence.split(" ") for sentence in sentences if len(sentence)>1]
split_sentences
# Out:
# [['thammasat', 'int'],
#  ['sc'],
#  ['tech',
#   'vol',
#   'january',
#   'april',
#   'cmos',
#   'capacitorlesscurrent',
#   'tunable',
#   'pass',
#   'filter',
#   'usingcurrent',
#   'mirrorsbanlue',
#   'srisuchinwong',
#   'adisorn',
#   'leelasantithamelectrical',
#   'engineering',
#   'program',
#   'sirindhorn',
#   'international',
#   'institute',
#   'technology',
#   'thammasat',
#   'university',
#   'box',
#   'thammasat',
#   'rangsit',
#   'post',
#   'office',
#   'patumthani',
#   'thailand',
#   'tel',
#   'fax',
#   'banlue',
#   'siit',
#   'tu',
#   'ac',
#   'thabstracta',
#   'cmos',
#   'capacitorless',
#   'current',
#   'tunable',
#   'pass',
#   'filter',
#   'using',
#   'current',
#   'mirrors',
#   'presentedthrough',
#   'use',
#   'mos',
#   'internal',
#   'capacitances'],
#  ['frequency',
#   'fo',
#   'magnitude',
#   'phaseshift',
#   'transfer',
#   'function',
#   'approximately',
#   'db',
#   'respectively',
#   'tunable',
#   'thebias',
#   'current'],
#  ['maximum',
#   'useful',
#   'fo',
#   'excess',
#   'mhz',
#   'depending',
#   'internal',
#   'parameters'],
#  ['introductionall',
#   'pass',
#   'filters',
#   'utilised',
#   'manyapplications',
#   'sinusoidal',
#   'quadratureoscillators'],
#  ['techniques',
#   'integrable',
#   'pass',
#   'filters',
#   'employ',
#   'relatively',
#   'large',
#   'externalcapacitors',
#   'therefore',
#   'operatingfrequencies',
#   'relatively',
#   'high',
#   'tl',
#   'recently',
#   'capacitorless',
#   'techniques',
#   'haveexploited',
#   'paracitic',
#   'capacitances',
#   'ofbjts',
#   'high',
#   'frequency',
#   'pass',
#   'filters',
#   'orintegrators',
#   'also',
#   'internal',
#   'capacitancesof',
#   'mos',
#   'high',
#   'frequency',
#   'bandpass',
#   'filters',
#   'switched',
#   'current',
#   'circuits',
#   'paper',
#   'high',
#   'frequency',
#   'cmoscapacitorless',
#   'current',
#   'tunable',
#   'pass',
#   'filter',
#   'usingcurrent',
#   'mirrors',
#   'presented',
#   'use',
#   'ofthe',
#   'mos',
#   'internal',
#   'capacitances'],
#  ['frequency',
#   'iwhere',
#   'magnitude',
#   'phase',
#   'shift',
#   'thetransfer',
#   'function',
#   'approximately',
#   'db',
#   'respectively',
#   'tunable',
#   'biascurrent'],
#  ['maximum', 'useful', 'excess', 'mhz', 'depending', 'internal', 'parameters'],
#  ['circuitdescriptionsfigure',
#   'shows',
#   'circuit',
#   'cmoscapacitorless',
#   'current',
#   'tunable',
#   'pass',
#   'filter'],
#  ['thecircuit',
#   'consists',
#   'current',
#   'mirrors',
#   'formed',
#   'fivenmos',
#   'transistors',
#   'ql',
#   'three',
#   'currentsources'],
#  ['ql', 'identical', 'andthe', 'aspect', 'ratios', 'wl'],
#  ['aspect', 'ratios', 'ofq', 'separated', 'two', 'cases'],
#  ['thefirst', 'case', 'ratios', 'wllrespectively'],
#  ['second', 'case', 'ratios', 'wll', 'respectively'],
#  ['small',
#   'signalinput',
#   'current',
#   'applied',
#   'drain',
#   'ql',
#   'andthe',
#   'resulting',
#   'small',
#   'signal',
#   'output',
#   'current',
#   'io',
#   'istaken',
#   'drain'],
#  ['ideal',
#   'analysisfor',
#   'mos',
#   'transistor',
#   'unity',
#   'currentgain',
#   'frequency',
#   'equal',
#   'cg',
#   'cga',
#   'cr',
#   'ly',
#   'vcs',
#   'vr',
#   'cg',
#   'cea',
#   'ceu',
#   'ate',
#   'mos',
#   'internalcapacitances'],
#  ['subscripts',
#   'standfor',
#   'gate',
#   'source',
#   'drain',
#   'body',
#   'mostransistor'],
#  ['gate', 'source', 'voltage'],
#  ['isthe', 'usual', 'threshold', 'voltage', 'biascurrent'],
#  ['refening',
#   'figure',
#   'small',
#   'signalcurrent',
#   'yields',
#   'stwhere',
#   'time',
#   'constant',
#   'tu',
#   'cje',
#   'cu',
#   'cr',
#   'cgu',
#   'cg',
#   'cga',
#   'ceu',
#   'cg',
#   'cgu',
#   'rand',
#   'qd',
#   'vcs'],
#  ['subscripts', 'refer', 'ql'],
#  ['similarly', 'small', 'signalcurrent', 'equal', 'toi'],
#  ['srb',
#   'time',
#   'constant',
#   'cjg',
#   'nc',
#   'cr',
#   'cru',
#   'cg',
#   'cga',
#   'cru',
#   'qd',
#   'vcso',
#   'vr'],
#  ['subscripts', 'refer', 'addition', 'io'],
#  ['therefore',
#   'transferfunction',
#   'ijir',
#   'yieldst',
#   'sr',
#   'sro',
#   'sinusoidal',
#   'input',
#   'magnitude',
#   'andphase',
#   'shift',
#   'ofequation',
#   'ofthe',
#   'formm',
#   'logq',
#   'tan',
#   'rot',
#   'equation',
#   'considered',
#   'two',
#   'cases'],
#  ['inthe',
#   'first',
#   'case',
#   'rb',
#   'equation',
#   'reducedto',
#   'first',
#   'order',
#   'pass',
#   'filter',
#   'formthammasat',
#   'int'],
#  ['sc'],
#  ['tech', 'vol'],
#  ['january',
#   'april',
#   'seen',
#   'oo',
#   'ro',
#   'tunable',
#   'bias',
#   'current',
#   'hencethe',
#   'name',
#   'current',
#   'tunable'],
#  ['simulation',
#   'resultsthe',
#   'performance',
#   'circuit',
#   'shown',
#   'infigure',
#   'simulated',
#   'using',
#   'spice',
#   'andall',
#   'transistors',
#   'saturation',
#   'mode'],
#  ['thecmos',
#   'transistors',
#   'modeled',
#   'alcatelmietec',
#   'pm',
#   'cmos',
#   'md',
#   'technologyfrom',
#   'europractice'],
#  ['width', 'andlength', 'equal', 'pm'],
#  ['supplyvoltage',
#   'vcc',
#   'table',
#   'ishows',
#   'internal',
#   'capacitances',
#   'ql',
#   'table',
#   'shows',
#   'values',
#   'tu',
#   'table',
#   'intemal',
#   'capacitances',
#   'ql',
#   'table'],
#  ['values',
#   'tu',
#   'ta',
#   'let',
#   'aspect',
#   'ratios',
#   'land',
#   'wll',
#   'respectively',
#   'represent',
#   'anapproximated',
#   'example',
#   'pass',
#   'filtersdescribed',
#   'first',
#   'case',
#   'tu'],
#  ['thiscase', 'db', 'respectively'],
#  ['case',
#   'figure',
#   'depicts',
#   'al',
#   'versus',
#   'iusing',
#   'dotted',
#   'solid',
#   'lines',
#   'expected',
#   'andsimulated',
#   'results',
#   'respectively',
#   'hand',
#   'let',
#   'aspect',
#   'ratio',
#   'ofq',
#   'wl',
#   'respectively',
#   'represent',
#   'example',
#   'approximatedall',
#   'pass',
#   'filter',
#   'described',
#   'second',
#   'case',
#   'sr',
#   'tg',
#   'srr',
#   'case',
#   'magnitude',
#   'phase',
#   'shift',
#   'ofequation',
#   'db',
#   'respectively',
#   'atthe',
#   'frequency',
#   'cdr',
#   'fororr',
#   'tu',
#   'ql',
#   'ca',
#   'qd',
#   'vcso',
#   'vr',
#   'cb',
#   'second',
#   'case',
#   'equation',
#   'maybe',
#   'approximated',
#   'pass',
#   'filter',
#   'mdescribed',
#   'approaches',
#   'db',
#   'oand',
#   'ojo',
#   'hror',
#   'forl',
#   'oratiosc'],
#  ['ql'],
#  ['llxl', 'wu', 'xl', 'wtl', 'xl', 'wl', 'wtl', 'ratioscurrenl', 'rra', 'vcs'],
#  ['lr'],
#  ['lq', 'lt', 'wll'],
#  ['case', 'andq', 'db', 'respectively'],
#  ['acase',
#   'figure',
#   'shows',
#   'oj',
#   'versus',
#   'using',
#   'dotted',
#   'solid',
#   'lines',
#   'theexpected',
#   'simulated',
#   'results',
#   'respectively'],
#  ['itcan',
#   'seen',
#   'figures',
#   'theerpected',
#   'simulated',
#   'results',
#   'resonablygood',
#   'fits',
#   'figure',
#   'shows',
#   'magnitude',
#   'db',
#   'andphase',
#   'shift',
#   'degrees',
#   'versusfrequency',
#   'hz',
#   'bias',
#   'current',
#   'pa',
#   'pa',
#   'first',
#   'case',
#   'tu',
#   'secondcase',
#   'respectively'],
#  ['seen',
#   'fromfigure',
#   'frequency',
#   'phase',
#   'shift',
#   'first',
#   'case',
#   'second',
#   'case',
#   'areapproximately',
#   'mhz',
#   'ghz',
#   'respectively',
#   'whilst',
#   'correspondingmagnitude',
#   'approximately'],
#  ['db', 'db', 'respectively'],
#  ['discussionsit',
#   'seen',
#   'figures',
#   'foof',
#   'first',
#   'case',
#   'tu',
#   'lower',
#   'fo',
#   'thesecond',
#   'case',
#   'tu',
#   'maximum',
#   'useful',
#   'foare',
#   'approximately',
#   'mhz',
#   'ghz',
#   'respectively'],
#  ['hand',
#   'firstcase',
#   'better',
#   'ofthe',
#   'second',
#   'case',
#   'maybe',
#   'amplified',
#   'wide',
#   'band',
#   'amplifierfor',
#   'use'],
#  ['applications',
#   'highfrequencies',
#   'second',
#   'case',
#   'tr',
#   'beconsidered',
#   'attractive',
#   'first',
#   'case',
#   'tu',
#   'ru',
#   'terms',
#   'higher',
#   'value',
#   'tu',
#   'thetwo',
#   'cases'],
#  ['small',
#   'signal',
#   'operation',
#   'idealcurrent',
#   'sources',
#   'input',
#   'outputimpedances',
#   'circuit',
#   'shown',
#   'figure',
#   'arezin',
#   'st',
#   'zo',
#   'rj',
#   'respectively',
#   'ro',
#   'finite',
#   'resistance',
#   'ofmos',
#   'drain',
#   'source',
#   'occurring',
#   'fromthe',
#   'effect',
#   'channel',
#   'length',
#   'modulation'],
#  ['theinput',
#   'impedance',
#   'typical',
#   'value',
#   'ofapproximately',
#   'llg',
#   'low',
#   'frequency'],
#  ['theoutput',
#   'impedance',
#   'improved',
#   'theuse',
#   'conventional',
#   'cascode',
#   'techniques',
#   'anexpense',
#   'lower',
#   'due',
#   'additional',
#   'internalcapacitances',
#   'ideal',
#   'current',
#   'sources',
#   'shown',
#   'figurei',
#   'realized',
#   'practical',
#   'pmoscurrent',
#   'sources',
#   'fo',
#   'magnitude',
#   'db',
#   'degrees',
#   'versus',
#   'may',
#   'slightly',
#   'decreasedbecause',
#   'additional',
#   'capacitance',
#   'apmos',
#   'transistor'],
#  ['however'],
#  ['source', 'isthammasat', 'int'],
#  ['sc'],
#  ['tech',
#   'vol',
#   'january',
#   'april',
#   'connected',
#   'ihe',
#   'body',
#   'therefore',
#   'ca',
#   'cauwhere',
#   'ca',
#   'usually',
#   'neglected'],
#  ['conclusionsa',
#   'cmos',
#   'capacitorless',
#   'current',
#   'tunableall',
#   'pass',
#   'filter',
#   'using',
#   'current',
#   'mirrors',
#   'beenpresented',
#   'use',
#   'mos',
#   'internalcapacitances'],
#  ['frequency',
#   'fo',
#   'themagnitude',
#   'phase',
#   'shift',
#   'transferfunction',
#   'approximately',
#   'db',
#   'respectively',
#   'tunable',
#   'bias',
#   'current',
#   'maximum',
#   'useful',
#   'excess',
#   'mhzdepending',
#   'internal',
#   'parameters'],
#  ['acknowledgementsthe',
#   'authors',
#   'grateful',
#   'royalgolden',
#   'jubilee',
#   'phd',
#   'proeram',
#   'financialsupports'],
#  ['referencestl',
#   'pookaiyaudom',
#   'samootrut',
#   'current',
#   'mirror',
#   'phase',
#   'shifter',
#   'oscillatorelectron'],
#  ['lett', 'vol'],
#  ['january',
#   'pp',
#   'bult',
#   'walling',
#   'cmos',
#   'analogcontinuous',
#   'time',
#   'delay',
#   'line',
#   'withadaptive',
#   'delay',
#   'time',
#   'control',
#   'ieee',
#   'ofsolid',
#   'state',
#   'circuits',
#   'vol'],
#  ['june',
#   'pp',
#   'higashimura',
#   'current',
#   'mode',
#   'allpassfilter',
#   'using',
#   'ftfn',
#   'groundedcapacitor',
#   'electron'],
#  ['lett', 'vol'],
#  ['june', 'pp'],
#  ['comer', 'comer'],
#  ['gonzales',
#   'high',
#   'frequency',
#   'integrablebandpass',
#   'filter',
#   'configuration',
#   'ieeetransactions',
#   'circuits',
#   'systems',
#   'il',
#   'analog',
#   'digital',
#   'signal',
#   'processing',
#   'vol',
#   'october',
#   'pp',
#   'pookaiyaudom',
#   'mahattanakul',
#   'volt',
#   'high',
#   'frequency',
#   'capacitorlesselectronically',
#   'tunable',
#   'log',
#   'domainoscillator',
#   'proceedings',
#   'ieeeinternational',
#   'symposium',
#   'circuits',
#   'andsystems',
#   'iscas',
#   'vol',
#   'pp'],
#  ['tang'],
#  ['kasperkovitz',
#   'ghz',
#   'monolithic',
#   'quadrature',
#   'mixeroscillator',
#   'direct',
#   'conversion',
#   'satellitereceivers',
#   'proceedings',
#   'ieeeintemational',
#   'solid',
#   'state',
#   'circuitsconference',
#   'pp'],
#  ['uit',
#   'lnagasawa',
#   'hyogo',
#   'sekine',
#   'mhz',
#   'cmos',
#   'continuous',
#   'timecurrent',
#   'mode',
#   'filter',
#   'using',
#   'gate',
#   'sourcecapacitance',
#   'mosfet',
#   'ispacs',
#   'pp'],
#  ['toumazou', 'hughes', 'battersby'],
#  ['ed'],
#  ['switched',
#   'currents',
#   'analoguetechnique',
#   'digital',
#   'technology',
#   'ieecircuits',
#   'systems',
#   'series',
#   'short',
#   'runpress',
#   'ltd',
#   'exeter',
#   'uk',
#   'thammasat',
#   'int'],
#  ['sc'],
#  ['tech',
#   'vol',
#   'january',
#   'april',
#   'sedra',
#   'smith',
#   'microelectronic',
#   'circuits',
#   'oxforduniversity',
#   'press'],
#  ['baker', 'li'],
#  ['boyce',
#   'cmos',
#   'circuit',
#   'design',
#   'layout',
#   'andsimulation',
#   'ieee',
#   'press',
#   'u',
#   'loc',
#   'ifigure',
#   'schematic',
#   'diagram',
#   'cmos',
#   'capacitorless',
#   'current',
#   'tunable',
#   'pass',
#   'filter',
#   'simulated',
#   'frcqucncyexpected',
#   'magnitudethammasat',
#   'int'],
#  ['sc'],
#  ['tech', 'vol'],
#  ['january',
#   'april',
#   'current',
#   'figure',
#   'frequency',
#   'fo',
#   'hz',
#   'magnitude',
#   'db',
#   'versus',
#   'theaspect',
#   'ratios',
#   'first',
#   'case',
#   'wl',
#   'wtl',
#   'respectively',
#   'figure',
#   'frequency',
#   'fo',
#   'hz',
#   'magnitude',
#   'db',
#   'versus',
#   'theaspect',
#   'ratios',
#   'second',
#   'case',
#   'wll',
#   'respectively',
#   'fh',
#   'aoo',
#   'lce',
#   'evegioon'],
#  ['egi',
#   'vtt',
#   'ertr',
#   'bl',
#   'nioisimulatcd',
#   'frcquencyexpected',
#   'magnitude',
#   'iobnoa',
#   'hbira',
#   'hi',
#   'thammasat',
#   'int'],
#  ['sc'],
#  ['tech',
#   'vol',
#   'january',
#   'april',
#   'le',
#   'frequency',
#   'io',
#   'figure',
#   'magnitude',
#   'db',
#   'phase',
#   'shift',
#   'degrees',
#   'versus',
#   'frequency',
#   'hz',
#   'ua',
#   'ua',
#   'first',
#   'case',
#   'secondcase',
#   'ra',
#   'rb',
#   'respectively',
#   'le',
#   'lclle'],
#  ['ieee',
#   'low',
#   'power',
#   'low',
#   'mismatch',
#   'low',
#   'glitch',
#   'class',
#   'ab',
#   'first',
#   'generation',
#   'switched',
#   'current',
#   'memory',
#   'cell',
#   'applications',
#   'san',
#   'um',
#   'srisuchinwong',
#   'tantaratana',
#   'school',
#   'communications',
#   'instrumentations',
#   'control',
#   'systems',
#   'sirindhorn',
#   'international',
#   'institute',
#   'technology',
#   'thammasat',
#   'university',
#   'po',
#   'box',
#   'thammasat',
#   'rangsit',
#   'post',
#   'office',
#   'pathumtani',
#   'thailand',
#   'banlue',
#   'siit',
#   'tu',
#   'ac',
#   'th',
#   'abstractin',
#   'paper',
#   'low',
#   'power',
#   'low',
#   'mismatch',
#   'low',
#   'glitch',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'switched',
#   'current',
#   'memory',
#   'cell',
#   'presented'],
#  ['technique',
#   'relatively',
#   'simple',
#   'based',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell'],
#  ['power', 'supply'],
#  ['average',
#   'low',
#   'power',
#   'consumption',
#   'maximum',
#   'useful',
#   'sampling',
#   'frequency',
#   'mhz'],
#  ['comparisons', 'techniques', 'presented'],
#  ['paper',
#   'demonstrates',
#   'better',
#   'output',
#   'waveforms',
#   'terms',
#   'low',
#   'offset',
#   'mismatch',
#   'errors',
#   'low',
#   'glitches'],
#  ['applications',
#   'delay',
#   'cell',
#   'modified',
#   'bilinear',
#   'integrator',
#   'also',
#   'demonstrated'],
#  ['introduction',
#   'switched',
#   'current',
#   'si',
#   'memory',
#   'cell',
#   'well',
#   'known',
#   'basic',
#   'building',
#   'block',
#   'analogue',
#   'sampled',
#   'data',
#   'signal',
#   'processing',
#   'signals',
#   'represented',
#   'current',
#   'samples'],
#  ['two',
#   'basic',
#   'ca',
#   'tegories',
#   'st',
#   'generation',
#   'nd',
#   'generation',
#   'si',
#   'memory',
#   'cells',
#   'shown',
#   'figs'],
#  ['respectively'],
#  ['although',
#   'advantages',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'include',
#   'low',
#   'level',
#   'transient',
#   'glitches',
#   'possible',
#   'non',
#   'unity',
#   'current',
#   'gain',
#   'simple',
#   'single',
#   'phase',
#   'clock',
#   'scheme',
#   'disadvantage',
#   'need',
#   'two',
#   'transistors'],
#  ['vulnerable', 'mismatch', 'errors', 'power', 'consumptions'],
#  ['nd',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'alternatively',
#   'employs',
#   'single',
#   'memory',
#   'transi',
#   'stor',
#   'initially',
#   'without',
#   'mirrored',
#   'transistor',
#   'order',
#   'avoid',
#   'mismatch',
#   'errors',
#   'reduce',
#   'power',
#   'consumption'],
#  ['however',
#   'three',
#   'consequent',
#   'drawbacks',
#   'presence',
#   'large',
#   'amplitude',
#   'transient',
#   'glitches',
#   'ii',
#   'absence',
#   'output'],
#  ['return',
#   'zero',
#   'sampling',
#   'phase',
#   'iii',
#   'direct',
#   'output',
#   'ideally',
#   'provides',
#   'unity',
#   'current',
#   'gain',
#   'whilst',
#   'non',
#   'unity',
#   'current',
#   'gains',
#   'required',
#   'applications',
#   'provided',
#   'immediately',
#   'although',
#   'problem',
#   'remedied',
#   'use',
#   'three',
#   'phase',
#   'clock',
#   'scheme',
#   'additional',
#   'clock',
#   'complexity',
#   'unattractive'],
#  ['similarly',
#   'problems',
#   'ii',
#   'iii',
#   'removed',
#   'using',
#   'additional',
#   'mirrored',
#   'transistor',
#   'tb',
#   'solution',
#   'also',
#   'introduces',
#   'additional',
#   'power',
#   'consumptions',
#   'mismatch',
#   'errors',
#   'previously',
#   'found',
#   'st',
#   'generation',
#   'si',
#   'cell'],
#  ['addition',
#   'generations',
#   'encounter',
#   'two',
#   'common',
#   'errors',
#   'known',
#   'conduction',
#   'errors',
#   'charge',
#   'injection',
#   'errors',
#   'although',
#   'several',
#   'new',
#   'techniques',
#   'widely',
#   'suggested',
#   'reductions',
#   'two',
#   'errors'],
#  ['generations',
#   'class',
#   'bias',
#   'techniques',
#   'typically',
#   'employed',
#   'therefore',
#   'limit',
#   'signal',
#   'handling',
#   'capability',
#   'bias',
#   'current'],
#  ['large',
#   'signal',
#   'handling',
#   'requires',
#   'large',
#   'bias',
#   'currents',
#   'leading',
#   'increase',
#   'power',
#   'consumption'],
#  ['recently',
#   'class',
#   'ab',
#   'si',
#   'memory',
#   'cell',
#   'based',
#   'nd',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'mirrored',
#   'output',
#   'shown',
#   'fig'],
#  ['developed',
#   'low',
#   'power',
#   'consumption',
#   'signal',
#   'swing',
#   'iin',
#   'class',
#   'ab',
#   'well',
#   'excess',
#   'bias',
#   'current'],
#  ['however',
#   'problems',
#   'large',
#   'transient',
#   'glitches',
#   'associated',
#   'nd',
#   'generation',
#   'si',
#   'cell',
#   'remain',
#   'evident'],
#  ['particular',
#   'class',
#   'ab',
#   'si',
#   'memory',
#   'cell',
#   'based',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'never',
#   'clearly',
#   'suggested'],
#  ['paper',
#   'low',
#   'power',
#   'low',
#   'mismatch',
#   'low',
#   'glitch',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'switched',
#   'current',
#   'memory',
#   'cell',
#   'presented'],
#  ['technique',
#   'relatively',
#   'simple',
#   'based',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell'],
#  ['power', 'supply'],
#  ['average',
#   'low',
#   'power',
#   'consumption',
#   'maximum',
#   'useful',
#   'sampling',
#   'frequency',
#   'mhz'],
#  ['comparisons', 'techniques', 'presented'],
#  ['paper',
#   'demonstrates',
#   'better',
#   'output',
#   'waveforms',
#   'terms',
#   'low',
#   'offset',
#   'mismatch',
#   'errors',
#   'low',
#   'glitches'],
#  ['applications',
#   'delay',
#   'cell',
#   'modified',
#   'bilinear',
#   'integrator',
#   'also',
#   'demonstrated'],
#  ['proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'fig',
#   'depicts',
#   'proposed',
#   'low',
#   'power',
#   'low',
#   'mismatch',
#   'low',
#   'glitch',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell'],
#  ['circuit',
#   'consists',
#   'two',
#   'diode',
#   'connected',
#   'transistors',
#   'two',
#   'memory',
#   'transistors',
#   'using',
#   'simple',
#   'single',
#   'phase',
#   'clock'],
#  ['sampling', 'phase', 'vgs', 'gs', 'vgs', 'gs'],
#  ['gs',
#   'vgs',
#   'vgs',
#   'gs',
#   'gate',
#   'source',
#   'voltage',
#   'transistors',
#   'respectively'],
#  ['consequently',
#   'circuit',
#   'operates',
#   'class',
#   'ab',
#   'current',
#   'mirror',
#   'therefore',
#   'small',
#   'signal',
#   'output',
#   'current',
#   'iom',
#   'inversely',
#   'tracks',
#   'small',
#   'signal',
#   'input',
#   'current',
#   'iin',
#   'possible',
#   'non',
#   'unity',
#   'current',
#   'gain'],
#  ['iom'],
#  ['holding',
#   'phase',
#   'gate',
#   'capacitances',
#   'hold',
#   'voltages',
#   'vgs',
#   'vgs',
#   'respectively'],
#  ['om'],
#  ['domain',
#   'transfer',
#   'function',
#   'om',
#   'iin',
#   'clearly',
#   'half',
#   'period',
#   'delay',
#   'value',
#   'hm',
#   'ta',
#   'iinioaca',
#   'ta',
#   'na',
#   'na',
#   'jgj',
#   'vddtb',
#   'iincb',
#   'vddtb',
#   'iob',
#   'iob',
#   'jgjnb',
#   'nb',
#   'iincc',
#   'vddioc',
#   'ioc',
#   'nc',
#   'nc',
#   'cc',
#   'tc',
#   'tc',
#   'tc',
#   'tc',
#   'vss',
#   'giinc',
#   'vdd',
#   'iomn',
#   'vss',
#   'figure',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'nd',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'mirrored',
#   'output',
#   'existing',
#   'class',
#   'ab',
#   'si',
#   'memory',
#   'cell',
#   'proposed',
#   'low',
#   'power',
#   'low',
#   'mismatch',
#   'low',
#   'glitch',
#   'class',
#   'ab',
#   'si',
#   'memory',
#   'cell'],
#  ['iinc',
#   'vdd',
#   'iodt',
#   'vss',
#   'nd',
#   'nd',
#   'figure',
#   'class',
#   'ab',
#   'si',
#   'delay',
#   'cell',
#   'using',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells'],
#  ['performances', 'analysis'],
#  ['low',
#   'power',
#   'consumption',
#   'mismatch',
#   'errors',
#   'mismatch',
#   'errors',
#   'generally',
#   'depend',
#   'presence',
#   'bias',
#   'currents'],
#  ['st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'small',
#   'signal',
#   'input',
#   'current',
#   'cannot',
#   'exceed',
#   'bias',
#   'current',
#   'order',
#   'avoid',
#   'signal',
#   'clipping'],
#  ['consequently',
#   'large',
#   'bias',
#   'currents',
#   'required',
#   'large',
#   'input',
#   'currents',
#   'result',
#   'high',
#   'power',
#   'consumptions',
#   'also',
#   'large',
#   'mismatch',
#   'errors',
#   'contrast',
#   'signal',
#   'swing',
#   'class',
#   'ab',
#   'well',
#   'excess',
#   'bias',
#   'currents'],
#  ['comparison',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'requires',
#   'much',
#   'lower',
#   'bias',
#   'currents',
#   'therefore',
#   'enables',
#   'lower',
#   'power',
#   'consumption',
#   'also',
#   'lower',
#   'mismatch',
#   'errors'],
#  ['low',
#   'transient',
#   'glitchestransient',
#   'glitches',
#   'generally',
#   'caused',
#   'transitions',
#   'high',
#   'low',
#   'impedance'],
#  ['st',
#   'generation',
#   'si',
#   'memory',
#   'cell',
#   'input',
#   'output',
#   'nodes',
#   'two',
#   'separated',
#   'terminals',
#   'therefore',
#   'avoid',
#   'direct',
#   'transitions',
#   'low',
#   'high',
#   'impedances'],
#  ['consequently', 'low', 'levels', 'glitches', 'st', 'generation'],
#  ['applications'],
#  ['class', 'ab', 'st', 'generation', 'si', 'delay', 'cell', 'fig'],
#  ['illustrates',
#   'class',
#   'ab',
#   'si',
#   'delay',
#   'cell',
#   'using',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells'],
#  ['small', 'signal', 'output', 'current', 'od'],
#  ['domain',
#   'transfer',
#   'function',
#   'hd',
#   'iod',
#   'iin',
#   'full',
#   'period',
#   'delay',
#   'value',
#   'hd'],
#  ['class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'modified',
#   'bilinear',
#   'integrator',
#   'several',
#   'si',
#   'integrators',
#   'reported',
#   'including',
#   'si',
#   'bilinear',
#   'integrators',
#   'bi',
#   'si',
#   'modified',
#   'bilinear',
#   'integrator',
#   'mbi'],
#  ['advantage', 'mbi', 'improvement', 'frequency', 'warping', 'effect'],
#  ['fig'],
#  ['llustrates',
#   'circuit',
#   'diagram',
#   'class',
#   'ab',
#   'si',
#   'mbi',
#   'based',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells'],
#  ['phase',
#   'output',
#   'current',
#   'giin',
#   'gi',
#   'appropriate',
#   'current',
#   'gain'],
#  ['meanwhile', 'phase', 'output', 'current', 'gi', 'gi'],
#  ['consequently',
#   'output',
#   'currents',
#   'phases',
#   'result',
#   'mbi',
#   'transfer',
#   'function',
#   'mbi',
#   'io',
#   'iin',
#   'domain',
#   'follows',
#   'hmbi',
#   'words',
#   'similar',
#   'outputs',
#   'delivered',
#   'phases',
#   'therefore',
#   'proposed',
#   'mbi',
#   'operates',
#   'twice',
#   'sampling',
#   'frequency'],
#  ['double', 'sampling', 'rate', 'compared', 'conventional', 'integrators'],
#  ['simulation',
#   'results',
#   'performances',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generationsi',
#   'memory',
#   'cell',
#   'delay',
#   'cell',
#   'integrator',
#   'mbi',
#   'simulated',
#   'spice'],
#  ['transistors',
#   'modeled',
#   'alcatel',
#   'mietec',
#   'cmos',
#   'md',
#   'technology',
#   'amc',
#   'europractice'],
#  ['minimum', 'width', 'length', 'transistor', 'respectively'],
#  ['aspect', 'ratios', 'nmos', 'switch', 'transistors', 'kept', 'minimum'],
#  ['threshold', 'voltages', 'nmos', 'pmos', 'respectively'],
#  ['ambient', 'temperature'],
#  ['clock', 'signal', 'vclk', 'resistive', 'load', 'rout'],
#  ['bias', 'current'],
#  ['supplied',
#   'voltage',
#   'dd',
#   'ss',
#   'small',
#   'signal',
#   'input',
#   'current',
#   'sinusoid',
#   'frequency',
#   'khz'],
#  ['sampling', 'frequency', 'mhz'],
#  ['table',
#   'summarizes',
#   'three',
#   'cases',
#   'ii',
#   'iii',
#   'aspect',
#   'ratios',
#   'memory',
#   'transistors',
#   'shown',
#   'fig'],
#  ['case',
#   'resulting',
#   'settling',
#   'time',
#   'settling',
#   'error',
#   'corresponding',
#   'maximum',
#   'useful',
#   'sampling',
#   'frequency',
#   'ms',
#   'proposed',
#   'memory',
#   'cell',
#   'summarized',
#   'table',
#   'whilst',
#   'fig'],
#  ['plots',
#   'corresponding',
#   'output',
#   'current',
#   'errors',
#   'versus',
#   'small',
#   'signal',
#   'input',
#   'currents'],
#  ['seen', 'table', 'fig'],
#  ['case',
#   'offers',
#   'higher',
#   'fms',
#   'mhz',
#   'iinc',
#   'vdd',
#   'vsst',
#   'gg',
#   'iout',
#   'figure',
#   'circuit',
#   'diagram',
#   'class',
#   'ab',
#   'si',
#   'mbi',
#   'based',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memo',
#   'ry',
#   'cells'],
#  ['operating',
#   'two',
#   'phase',
#   'clock',
#   'waveforms',
#   'table',
#   'three',
#   'cases',
#   'settling',
#   'time',
#   'settling',
#   'error',
#   'sampling',
#   'frequency',
#   'figure',
#   'output',
#   'current',
#   'errors',
#   'versus',
#   'small',
#   'signal',
#   'input',
#   'currents',
#   'cases',
#   'ii',
#   'iii',
#   'shown',
#   'table',
#   'larger',
#   'output',
#   'current',
#   'errors'],
#  ['contrast',
#   'case',
#   'iii',
#   'offers',
#   'lower',
#   'fms',
#   'mhz',
#   'lower',
#   'output',
#   'current',
#   'errors'],
#  ['consequently', 'aspect', 'ratio', 'case', 'iii', 'chosen', 'simulations'],
#  ['figs'],
#  ['aspect',
#   'ratios',
#   'nmos',
#   'similar',
#   'whilst',
#   'aspect',
#   'ratios',
#   'pmos',
#   'similar'],
#  ['figs',
#   'illustrate',
#   'simulation',
#   'results',
#   'output',
#   'currents',
#   'existing',
#   'st',
#   'generation',
#   'existing',
#   'nd',
#   'generation',
#   'existing',
#   'class',
#   'ab',
#   'nd',
#   'generationand',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells',
#   'shown',
#   'figs'],
#  ['respectively'],
#  ['seen', 'fig'],
#  ['output', 'current', 'neatly', 'accurate'],
#  ['figs',
#   'problems',
#   'offset',
#   'errors',
#   'transient',
#   'glitches',
#   'obviously',
#   'evident'],
#  ['contrast', 'fig'],
#  ['demonstrates',
#   'neatly',
#   'accurate',
#   'output',
#   'current',
#   'problems',
#   'offset',
#   'errors',
#   'transient',
#   'glitches',
#   'clearly',
#   'apparent'],
#  ['power',
#   'consumption',
#   'figure',
#   'shows',
#   'simulation',
#   'results',
#   'output',
#   'currents',
#   'full',
#   'period',
#   'delay',
#   'cell',
#   'using',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells'],
#  ['figure',
#   'depicts',
#   'simulation',
#   'results',
#   'output',
#   'currents',
#   'modified',
#   'bilinear',
#   'integrator',
#   'mbi',
#   'using',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells'],
#  ['seen', 'figs'],
#  ['outputs',
#   'neatly',
#   'follow',
#   'expected',
#   'functions',
#   'problems',
#   'offset',
#   'errors',
#   'transient',
#   'glitches',
#   'clearly',
#   'evident'],
#  ['conclusionsin',
#   'paper',
#   'low',
#   'power',
#   'low',
#   'mismatch',
#   'low',
#   'glitch',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'switched',
#   'current',
#   'memory',
#   'cell',
#   'presented'],
#  ['technique',
#   'relatively',
#   'simple',
#   'based',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cell'],
#  ['power', 'supply'],
#  ['average',
#   'low',
#   'power',
#   'consumption',
#   'maximum',
#   'useful',
#   'sampling',
#   'frequency',
#   'mhz'],
#  ['comparisons', 'techniques', 'presented'],
#  ['paper',
#   'demonstrated',
#   'better',
#   'output',
#   'waveforms',
#   'terms',
#   'low',
#   'offset',
#   'mismatch',
#   'errors',
#   'low',
#   'glitches'],
#  ['applications',
#   'delay',
#   'cell',
#   'modified',
#   'bilinear',
#   'integrator',
#   'also',
#   'demonstrated'],
#  ['acknowledgements',
#   'authors',
#   'grateful',
#   'national',
#   'electronics',
#   'computer',
#   'technology',
#   'center',
#   'nectec',
#   'supports',
#   'research',
#   'grant'],
#  ['cases',
#   'transistors',
#   'ts',
#   'ns',
#   'fms',
#   'mhz',
#   'ii',
#   'iii',
#   'small',
#   'signal',
#   'input',
#   'currents',
#   'output',
#   'current',
#   'errors',
#   'iiiiii',
#   'time',
#   'us',
#   'u',
#   'time',
#   'us',
#   'u',
#   'time',
#   'us',
#   'u',
#   'time',
#   'us',
#   'u',
#   'case',
#   'figure',
#   'simulation',
#   'results',
#   'output',
#   'currents',
#   'st',
#   'generation',
#   'nd',
#   'generation',
#   'class',
#   'ab',
#   'nd',
#   'generation',
#   'proposed',
#   'class',
#   'ab',
#   'st',
#   'generation',
#   'si',
#   'memory',
#   'cells'],
#  ['u', 'u', 'time', 'us', 'u'],
#  ['references',
#   'toumazou',
#   'hughes',
#   'batterby',
#   'switched',
#   'current',
#   'analogue',
#   'technique',
#   'digital',
#   'technology',
#   'iee',
#   'circuits',
#   'systems',
#   'series',
#   'short',
#   'run',
#   'press',
#   'ltd',
#   'exeter'],
#  ['jonsson',
#   'switched',
#   'current',
#   'signal',
#   'processing',
#   'conversion',
#   'circuits',
#   'kluwer',
#   'academic',
#   'publishers'],
#  ['sinn'],
#  ['roberts',
#   'comparison',
#   'first',
#   'second',
#   'generation',
#   'switched',
#   'current',
#   'cells',
#   'iscas',
#   'vol'],
#  ['pp'],
#  ['yang',
#   'masy',
#   'clock',
#   'feedthrough',
#   'analysis',
#   'cancellation',
#   'current',
#   'sample',
#   'hold',
#   'circuit',
#   'proceedings',
#   'iee',
#   'circuits',
#   'devices',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['oliaei',
#   'loumeau',
#   'low',
#   'supply',
#   'si',
#   'cell',
#   'using',
#   'threshold',
#   'control',
#   'iscas'],
#  ['kawahito',
#   'tadokora',
#   'cmos',
#   'class',
#   'ab',
#   'current',
#   'mirrors',
#   'precision',
#   'current',
#   'mode',
#   'analog',
#   'signal',
#   'processing',
#   'elements',
#   'ieee',
#   'transaction',
#   'circuits',
#   'systems',
#   'ii',
#   'vol'],
#  ['palmisano',
#   'pesini',
#   'true',
#   'low',
#   'voltage',
#   'cmos',
#   'class',
#   'ab',
#   'current',
#   'mirror',
#   'iscas',
#   'vol'],
#  ['oliaei', 'loumeao'],
#  ['glitch',
#   'reduction',
#   'second',
#   'generation',
#   'si',
#   'circuits',
#   'electronics',
#   'letters',
#   'vol'],
#  ['pp'],
#  ['lui'],
#  ['chen'],
#  ['tsao',
#   'wu',
#   'switched',
#   'current',
#   'modified',
#   'bilinwera',
#   'integrator',
#   'applications',
#   'iscas'],
#  ['time',
#   'magnitude',
#   'input',
#   'currentiinthe',
#   'output',
#   'currentioatime',
#   'magnitude',
#   'input',
#   'currentiinthe',
#   'output',
#   'currentiob',
#   'time',
#   'magnitude',
#   'input',
#   'currentiinthe',
#   'output',
#   'currentiomtime',
#   'magnitude',
#   'input',
#   'currentiinthe',
#   'output',
#   'currentioc',
#   'time',
#   'us',
#   'output',
#   'current',
#   'ua',
#   'input',
#   'current',
#   'iinthe',
#   'full',
#   'period',
#   'delayed',
#   'output',
#   'current',
#   'iodfigure',
#   'simulation',
#   'results',
#   'output',
#   'currents',
#   'full',
#   'period',
#   'delayed',
#   'cell',
#   'shown',
#   'fig'],
#  ['time',
#   'us',
#   'output',
#   'current',
#   'ua',
#   'input',
#   'current',
#   'iinthe',
#   'output',
#   'current',
#   'ioutfigure',
#   'simulation',
#   'results',
#   'output',
#   'currents',
#   'modified',
#   'bilinear',
#   'integrator',
#   'mbi',
#   'shown',
#   'fig'],
#  ['paper',
#   'postprint',
#   'paper',
#   'submitted',
#   'accepted',
#   'publication',
#   'electronics',
#   'letters',
#   'th',
#   'november',
#   'vol'],
#  ['pp'],
#  ['subject', 'institute', 'engineering', 'technology', 'copyright'],
#  ['copy', 'record', 'available', 'ie', 'digital', 'library'],
#  ['current',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'circuit',
#   'based',
#   'one',
#   'unity',
#   'gain',
#   'amplifier',
#   'srisuchinwong',
#   'treetanakorn',
#   'new',
#   'curr',
#   'ent',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'circuit',
#   'propose',
#   'based',
#   'single',
#   'unity',
#   'gain',
#   'amplifier'],
#  ['circuit',
#   'initial',
#   'ly',
#   'demonstrates',
#   'feasible',
#   'use',
#   'simple',
#   'unity',
#   'gain',
#   'amplifier',
#   'chaotic',
#   'jerk',
#   'oscillator'],
#  ['bifurcati', 'adjustable', 'using', 'current', 'source'],
#  ['chaotic', 'attractors', 'illustrated', 'plane', 'plane'],
#  ['latter',
#   'revealed',
#   'numerically',
#   'experimentally',
#   'simple',
#   'algebraic',
#   'sum',
#   'scaled'],
#  ['homoclinic', 'orbit', 'includ', 'ed'],
#  ['introduction',
#   'chaotic',
#   'behaviour',
#   'studi',
#   'ed',
#   'use',
#   'variety',
#   'methods',
#   'including',
#   'chaotic',
#   'signals',
#   'generated',
#   'electronic',
#   'circui',
#   'ts'],
#  ['chaotic',
#   'circuits',
#   'ha',
#   'particular',
#   'interest',
#   'owing',
#   'relatively',
#   'low',
#   'cost',
#   'feasible',
#   'applications',
#   'various',
#   'fields',
#   'science',
#   'technology'],
#  ['chaos', 'based', 'secure', 'communications'],
#  ['existing', 'chaotic', 'circuit', 'may', 'separated', 'two', 'types'],
#  ['type',
#   'involve',
#   'chaotic',
#   'oscillator',
#   'expressed',
#   'set',
#   'three',
#   'coupled',
#   'first',
#   'order',
#   'differential',
#   'equations'],
#  ['chua', 'circuit'],
#  ['type',
#   'ii',
#   'involves',
#   'chaotic',
#   'jerk',
#   'oscillator',
#   'express',
#   'ed',
#   'third',
#   'order',
#   'differential',
#   'equation',
#   'form',
#   'called',
#   'jerk',
#   'equation'],
#  ['type',
#   'ii',
#   'increasingly',
#   'drawn',
#   'much',
#   'attention',
#   'due',
#   'simplicity'],
#  ['recently',
#   'current',
#   'tunable',
#   'approach',
#   'es',
#   'reported',
#   'type',
#   'type',
#   'ii'],
#  ['addition',
#   'techniques',
#   'unity',
#   'gain',
#   'amplifiers',
#   'exploit',
#   'ed',
#   'sinusoidal',
#   'oscillators',
#   'also',
#   'chaotic',
#   'oscillator',
#   'type'],
#  ['chaotic',
#   'oscillator',
#   'type',
#   'based',
#   'either',
#   'chua',
#   'circuit',
#   'colpitts',
#   'oscillator'],
#  ['circuit',
#   'require',
#   'lots',
#   'unity',
#   'gain',
#   'amplifiers',
#   'therefore',
#   'somewhat',
#   'deteriorate',
#   'advantages',
#   'simplicity',
#   'low',
#   'cost',
#   'low',
#   'power',
#   'unity',
#   'gain',
#   'amplifier'],
#  ['circuit',
#   'physically',
#   'requir',
#   'ed',
#   'four',
#   'energy',
#   'storage',
#   'components'],
#  ['two',
#   'inductors',
#   'two',
#   'cap',
#   'acitors',
#   'although',
#   'circuit',
#   'mathematically',
#   'simplified',
#   'chaotic',
#   'oscillator',
#   'circuits',
#   'expressed',
#   'jerk',
#   'equation'],
#  ['particular',
#   'technique',
#   'single',
#   'unity',
#   'gain',
#   'amplifier',
#   'never',
#   'clearly',
#   'demonstrat',
#   'ed',
#   'chaotic',
#   'jerk',
#   'oscillator',
#   'type',
#   'ii'],
#  ['purpose',
#   'letter',
#   'present',
#   'new',
#   'current',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'circuit',
#   'based',
#   'one',
#   'unity',
#   'gain',
#   'amplifier'],
#  ['circuit',
#   'particularly',
#   'reveal',
#   'initial',
#   'use',
#   'simple',
#   'unity',
#   'gain',
#   'amplifier',
#   'chaotic',
#   'jerk',
#   'oscillator'],
#  ['bifurcation', 'tunable', 'using', 'current', 'source'],
#  ['homoclinic', 'orbit', 'also', 'depicted'],
#  ['fig'],
#  ['current',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'circuit',
#   'based',
#   'one',
#   'unity',
#   'gain',
#   'amplifier'],
#  ['circuit', 'realisation', 'fig'],
#  ['display',
#   'new',
#   'current',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'circuit',
#   'based',
#   'one',
#   'unity',
#   'gain',
#   'amplifier'],
#  ['op', 'amp', 'forms', 'simple', 'unity', 'gain', 'amplifier'],
#  ['series',
#   'parallel',
#   'network',
#   'rl',
#   'capacitive',
#   'voltage',
#   'divider',
#   'arrange',
#   'typical',
#   'res',
#   'onator',
#   'colpitts',
#   'oscillator'],
#  ['diode', 'provides', 'necessary', 'nonlinearity'],
#  ['constants', 'ormalis', 'ed', 'variables', 'defined'],
#  ['time',
#   'time',
#   'constants',
#   'rl',
#   'rl',
#   'resistor',
#   'rl',
#   'internal',
#   'resistance',
#   'resistor',
#   'vt',
#   'thermal',
#   'voltage',
#   'scaling',
#   'factor'],
#  ['set',
#   'three',
#   'coupled',
#   'first',
#   'order',
#   'different',
#   'ial',
#   'equations',
#   'fig'],
#  ['shown', 'aturation', 'current'],
#  ['consequently',
#   'transferr',
#   'ed',
#   'jerk',
#   'equation',
#   'form',
#   'shown',
#   'ca'],
#  ['jerk', 'equation', 'readily', 'adjustable', 'current', 'source'],
#  ['simulations',
#   'experiments',
#   'use',
#   'four',
#   'th',
#   'order',
#   'runge',
#   'kutta',
#   'integrator',
#   'numerical',
#   'simulation',
#   'jerk',
#   'equation',
#   'uses',
#   'step',
#   'size',
#   'vt',
#   'mv',
#   'vee',
#   'nitial',
#   'conditions'],
#  ['op', 'amp', 'diode', 'mbr'],
#  ['measured', 'values', 'polyester', 'capacitors', 'nf', 'nf', 'rl'],
#  ['therefore'],
#  ['adjustable', 'current', 'source', 'lm'],
#  ['sequence',
#   'numerical',
#   'trajectorie',
#   'plane',
#   'sequential',
#   'ly',
#   'illustrated',
#   'figs'],
#  ['ad'],
#  ['sequence',
#   'numerical',
#   'trajectorie',
#   'plane',
#   'sequent',
#   'ially',
#   'depicted',
#   'figs'],
#  ['eh'],
#  ['similar', 'manner', 'figs'],
#  ['eh', 'experimental', 'results', 'sequential', 'ly', 'displayed', 'figs'],
#  ['sequence',
#   'vc',
#   'vo',
#   'plane',
#   'vc',
#   'corresponds',
#   'scaled',
#   'vo',
#   'corresponds',
#   'scaled'],
#  ['vo', 'output', 'voltage', 'instrumentation', 'amplifier', 'ad', 'gain'],
#  ['input',
#   'voltage',
#   'vin',
#   'ad',
#   'voltage',
#   'across',
#   'inductive',
#   'current',
#   'il',
#   'converted',
#   'vin',
#   'ilr'],
#  ['output', 'voltage', 'ad', 'vo', 'ilr', 'il'],
#  ['ay', 'il', 'therefore', 'vo', 'appropriate', 'display', 'oscilloscope'],
#  ['numerical', 'results', 'shown', 'figs'],
#  ['eh',
#   'consistent',
#   'experimental',
#   'results',
#   'shown',
#   'figs',
#   'respectively'],
#  ['fig'],
#  ['trajectories',
#   'using',
#   'respect',
#   'ively',
#   'numerical',
#   'solution',
#   'plan',
#   'numerical',
#   'solution',
#   'plane',
#   'plane',
#   'oscilloscope',
#   'traces',
#   'vc',
#   'vo',
#   'plane',
#   'fig'],
#  ['show',
#   'numerical',
#   'plot',
#   'bifurcation',
#   'diagram',
#   'vertex',
#   'max',
#   'steps'],
#  ['period', 'doubling', 'route', 'chaos', 'obvious', 'fig'],
#  ['initial', 'condition', 'attractor', 'fig'],
#  ['depict', 'corresponding', 'largest', 'lyapunov', 'exponent', 'steps'],
#  ['step', 'runs', 'step', 'size'],
#  ['observed', 'figs'],
#  ['bifurcation', 'parameter'],
#  ['fig'],
#  ['bifurcation', 'diagram', 'max'],
#  ['fig'],
#  ['largest', 'lyapunov', 'exponent'],
#  ['equation', 'equilibrium', 'point'],
#  ['therefore',
#   'table',
#   'summarizes',
#   'two',
#   'xamples',
#   'eigenval',
#   'ues',
#   'nf',
#   'nf'],
#  ['example',
#   'consists',
#   'negative',
#   'real',
#   'eigenvalue',
#   'complex',
#   'conjugate',
#   'pair',
#   'eigenvalues'],
#  ['equilibrium', 'point', 'therefore', 'spiral', 'saddle', 'point', 'index'],
#  ['unstable', 'manifold', 'set', 'spatial', 'dimension'],
#  ['example',
#   'correspond',
#   'common',
#   'case',
#   'equilibrium',
#   'point',
#   'located',
#   'attractor',
#   'depicted',
#   'fig'],
#  ['example',
#   'corresponds',
#   'special',
#   'case',
#   'equilibrium',
#   'point',
#   'intersec',
#   'ts',
#   'attractor',
#   'illustrat',
#   'ed',
#   'homoclinic',
#   'orbit',
#   'fig'],
#  ['plane'],
#  ['orbit', 'clearly', 'join', 'equilibrium', 'point'],
#  ['unstable',
#   'manifold',
#   'set',
#   'intersects',
#   'stable',
#   'manifold',
#   'set',
#   'homoclinic',
#   'connection',
#   'exist',
#   'addition',
#   'satisfies',
#   'hil',
#   'nikov',
#   'condition',
#   'thereby',
#   'establishing',
#   'proof',
#   'chaos',
#   'circuit'],
#  ['table',
#   'examples',
#   'igenval',
#   'ues',
#   'example',
#   'nf',
#   'example',
#   'nf',
#   'fig'],
#  ['homoclinic', 'orbit', 'plane', 'example'],
#  ['conclusion',
#   'new',
#   'current',
#   'tunable',
#   'chaotic',
#   'erk',
#   'oscillator',
#   'describ',
#   'ed',
#   'employing',
#   'one',
#   'unity',
#   'gain',
#   'amplifier'],
#  ['circuit',
#   'particularly',
#   'demonstrated',
#   'initially',
#   'feasible',
#   'realisation',
#   'simple',
#   'unity',
#   'gain',
#   'amplifier',
#   'current',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'oscillator'],
#  ['curre', 'nt', 'source', 'exploited', 'bifurcation', 'parameter'],
#  ['chaotic',
#   'attractor',
#   'plane',
#   'depict',
#   'ed',
#   'numerically',
#   'experimentally',
#   'simple',
#   'algebraic',
#   'sum',
#   'scaled'],
#  ['homoclinic', 'connection', 'exists', 'illustration', 'homoclinic', 'orbit'],
#  ['acknowledgments',
#   'second',
#   'author',
#   'graceful',
#   'support',
#   'national',
#   'research',
#   'university',
#   'project',
#   'thailand',
#   'office',
#   'higher',
#   'education',
#   'commission'],
#  ['srisuchinwong',
#   'treetanakorn',
#   'sirindhorn',
#   'international',
#   'institute',
#   'technology',
#   'thammasat',
#   'university',
#   'pathum',
#   'thani',
#   'thailand',
#   'mail',
#   'banlue',
#   'siit',
#   'tu',
#   'ac',
#   'th',
#   'references',
#   'srisuchinwong',
#   'munmuangsaen',
#   'secure',
#   'communication',
#   'systems',
#   'based',
#   'upon',
#   'two',
#   'fold',
#   'masking',
#   'different',
#   'chaotic',
#   'attractors',
#   'including',
#   'modified',
#   'chaotic',
#   'attractors',
#   'using',
#   'static',
#   'dynamic',
#   'secret',
#   'keys',
#   'wipo',
#   'http',
#   'www',
#   'wipo',
#   'int',
#   'patentscope',
#   'search',
#   'en',
#   'wo',
#   'accessed',
#   'st',
#   'september',
#   'srisuchinwong',
#   'nopchinda',
#   'current',
#   'tunable',
#   'chaotic',
#   'jerk',
#   'oscillator',
#   'electron'],
#  ['lett', 'pp'],
#  ['piper',
#   'sprott',
#   'simple',
#   'autonomous',
#   'chaotic',
#   'circuits',
#   'ieee',
#   'trans'],
#  ['circuits', 'syst'],
#  ['ii', 'exp'],
#  ['brief', 'pp'],
#  ['srisuchinwong',
#   'munmuangsaen',
#   'four',
#   'current',
#   'tunable',
#   'chaotic',
#   'oscillators',
#   'set',
#   'two',
#   'diode',
#   'reversible',
#   'pairs',
#   'electron'],
#  ['lett', 'pp'],
#  ['srisuchinwong',
#   'amonchailertrat',
#   'realization',
#   'lambert',
#   'function',
#   'chaotic',
#   'circuit'],
#  ['circuit', 'syst'],
#  ['comp', 'art'],
#  ['papes',
#   'senani',
#   'new',
#   'rc',
#   'active',
#   'oscillator',
#   'configuration',
#   'employing',
#   'unity',
#   'gain',
#   'amplifiers',
#   'electron'],
#  ['lett', 'pp'],
#  ['pookaiyaudom',
#   'negative',
#   'feedback',
#   'circuits',
#   'oscillators',
#   'mahanakorn',
#   'university',
#   'technology',
#   'bangkok',
#   'nchez',
#   'pez',
#   'castro',
#   'hernandez',
#   'perez',
#   'trejo',
#   'morales',
#   'lopez',
#   'cante',
#   'michcol',
#   'carrasco',
#   'aguilar',
#   'implementation',
#   'chua',
#   'circuit',
#   'ugcs',
#   'international',
#   'conf'],
#  ['microelectronics',
#   'sh',
#   'arjah',
#   'united',
#   'arab',
#   'emirates',
#   'dec',
#   'ember',
#   'pp',
#   'sanchez',
#   'lopez',
#   'tlelo',
#   'cuautle',
#   'carrasco',
#   'aguilar',
#   'morales',
#   'lopez',
#   'cante',
#   'michcol',
#   'multi',
#   'scroll',
#   'chaotic',
#   'oscillator',
#   'employ',
#   'ing',
#   'ugcs',
#   'international',
#   'conf'],
#  ['electrical',
#   'communications',
#   'computers',
#   'san',
#   'andr',
#   'cholula',
#   'mexico',
#   'february',
#   'pp',
#   'chen',
#   'guo',
#   'gao',
#   'li'],
#  ['novel',
#   'ultra',
#   'wideband',
#   'microwave',
#   'chaotic',
#   'colpitts',
#   'oscillator',
#   'wireless',
#   'microwave',
#   'technology',
#   'conf'],
#  ['wamicon',
#   'orlando',
#   'usa',
#   'april',
#   'pp',
#   'tunable',
#   'current',
#   'largest',
#   'lyapunov',
#   'exponent'],
#  ['electronic',
#   'version',
#   'article',
#   'published',
#   'journal',
#   'ci',
#   'rcuits',
#   'systems',
#   'computers',
#   'vol'],
#  ['pages',
#   'article',
#   'doi',
#   'world',
#   'scientific',
#   'publishing',
#   'company',
#   'journal',
#   'url',
#   'www',
#   'worldscientific',
#   'com',
#   'worldscinet',
#   'jcsc',
#   'realization',
#   'lambert',
#   'function',
#   'chaotic',
#   'circuit',
#   'banlue',
#   'srisuchinwong',
#   'nithi',
#   'amonchailertrat',
#   'school',
#   'information',
#   'computer',
#   'communicati',
#   'technology',
#   'sirindhorn',
#   'international',
#   'institute',
#   'technology',
#   'thammasat',
#   'university',
#   'moo',
#   'tiwanont',
#   'road',
#   'bangkadi',
#   'mueang',
#   'pathum',
#   'thani',
#   'thailand',
#   'banlue',
#   'siit',
#   'tu',
#   'ac',
#   'th',
#   'nithi',
#   'siit',
#   'tu',
#   'ac',
#   'th',
#   'received',
#   'february',
#   'revised',
#   'may',
#   'accepted',
#   'july',
#   'new',
#   'chaotic',
#   'circuit',
#   'practically',
#   'realized',
#   'fo',
#   'first',
#   'time',
#   'using',
#   'lambert',
#   'function'],
#  ['circuit', 'consists', 'three', 'main', 'parts'],
#  ['first',
#   'part',
#   'employs',
#   'well',
#   'known',
#   'wilson',
#   'current',
#   'mirror',
#   'whereas',
#   'second',
#   'part',
#   'simple',
#   'resistor',
#   'th',
#   'two',
#   'connected',
#   'emitters',
#   'current',
#   'mirror'],
#  ['parts',
#   'form',
#   'new',
#   'circuit',
#   'lambert',
#   'function',
#   'enabling',
#   'term',
#   'emitter',
#   'current',
#   'simultaneously',
#   'appeared',
#   'sides',
#   'exponential',
#   'equation'],
#  ['nonlinear',
#   'equation',
#   'particularly',
#   'well',
#   'suited',
#   'realization',
#   'lamber',
#   'function'],
#  ['third',
#   'pa',
#   'rt',
#   'exploits',
#   'capacitor',
#   'inductor',
#   'capacitor',
#   'clc',
#   'network',
#   'resistor',
#   'conn',
#   'ected',
#   'nonlinear',
#   'circuit',
#   'lambert',
#   'function',
#   'allow',
#   'chaotic',
#   'oscillations'],
#  ['new',
#   'circuit',
#   'capable',
#   'lambert',
#   'function',
#   'current',
#   'tunable',
#   'chaotic',
#   'oscillator'],
#  ['keywords',
#   'lambert',
#   'function',
#   'chaotic',
#   'circu',
#   'current',
#   'tunable',
#   'bifurcation'],
#  ['introduction',
#   'studies',
#   'chaotic',
#   'circuits',
#   'systems',
#   'attracted',
#   'great',
#   'attention',
#   'due',
#   'variety',
#   'applications',
#   'science',
#   'technology'],
#  ['chaos', 'based', 'secure', 'communications'],
#  ['recently',
#   'lambert',
#   'function',
#   'progressively',
#   'recognized',
#   'solutions',
#   'various',
#   'fields',
#   'example',
#   'mathematics',
#   'physics',
#   'chemistry',
#   'analytical',
#   'aspects',
#   'chaotic',
#   'systems'],
#  ['although',
#   'several',
#   'electronic',
#   'circuits',
#   'already',
#   'implemented',
#   'lambert',
#   'function',
#   'none',
#   'feasibly',
#   'demonstrated',
#   'chaotic',
#   'circuit'],
#  ['natural',
#   'wond',
#   'er',
#   'whether',
#   'lambert',
#   'function',
#   'electronically',
#   'implemented',
#   'chaotic',
#   'circuit'],
#  ['new',
#   'realiza',
#   'tion',
#   'electronic',
#   'circuit',
#   'capable',
#   'lambert',
#   'function',
#   'chaotic',
#   'circuit',
#   'remained',
#   'discovered'],
#  ['lambert',
#   'function',
#   'defined',
#   'solution',
#   'transcendental',
#   'equation',
#   'wew'],
#  ['function', 'multi', 'valued', 'function', 'defined', 'general', 'complex'],
#  ['real', 'two', 'possible', 'branches'],
#  ['first', 'branch', 'satisfies', 'called', 'principal', 'branch'],
#  ['second',
#   'branch',
#   'srisuchinwong',
#   'amonchailertrat',
#   'satisfies',
#   'called'],
#  ['real', 'single', 'real', 'value', 'also', 'belongs', 'principal', 'branch'],
#  ['continuous',
#   'chaotic',
#   'flows',
#   'poincar',
#   'bendixson',
#   'theorem',
#   'implies',
#   'necessity',
#   'least',
#   'three',
#   'energy',
#   'storage',
#   'elements',
#   'capacitors',
#   'inductors',
#   'least',
#   'one',
#   'nonlinearity'],
#  ['use',
#   'three',
#   'energy',
#   'stora',
#   'ge',
#   'elements',
#   'example',
#   'three',
#   'capacitor',
#   'ccc',
#   'network',
#   'inductor',
#   'capacitor',
#   'inductor',
#   'lcl',
#   'network',
#   'capacitor',
#   'inductor',
#   'capacitor',
#   'clc',
#   'network'],
#  ['clc',
#   'network',
#   'particular',
#   'interest',
#   'refers',
#   'lc',
#   'tank',
#   'circuit',
#   'single',
#   'inductor',
#   'typically',
#   'used',
#   'building',
#   'block',
#   'commonly',
#   'found',
#   'classical',
#   'sinusoidal',
#   'oscillators'],
#  ['colpitts',
#   'oscillators',
#   'also',
#   'several',
#   'existing',
#   'chaotic',
#   'oscillators'],
#  ['although',
#   'clc',
#   'sinusoidal',
#   'oscillator',
#   'based',
#   'single',
#   'wilson',
#   'current',
#   'mirror',
#   'known',
#   'clc',
#   'chaotic',
#   'oscillator',
#   'based',
#   'single',
#   'wilson',
#   'current',
#   'mirror',
#   'never',
#   'demonstrated'],
#  ['paper',
#   'new',
#   'electronic',
#   'circuit',
#   'realized',
#   'lambert',
#   'function',
#   'capable',
#   'practical',
#   'application',
#   'first',
#   'time',
#   'new',
#   'chaotic',
#   'circuit'],
#  ['well',
#   'known',
#   'wilson',
#   'current',
#   'mirror',
#   'single',
#   'resistor',
#   'two',
#   'connected',
#   'emitters',
#   'current',
#   'mirror',
#   'form',
#   'new',
#   'circuit',
#   'lambert',
#   'function',
#   'providing',
#   'exponential',
#   'equation',
#   'term',
#   'emitter',
#   'current',
#   'simu',
#   'ltaneously',
#   'appear',
#   'sides'],
#  ['nonlinear',
#   'equation',
#   'appropriately',
#   'suitable',
#   'fo',
#   'realization',
#   'lambert',
#   'function'],
#  ['clc',
#   'network',
#   'resistor',
#   'connected',
#   'th',
#   'wilson',
#   'current',
#   'mirror',
#   'enable',
#   'chaotic',
#   'oscillation'],
#  ['new',
#   'circuit',
#   'capable',
#   'lambert',
#   'function',
#   'also',
#   'chaotic',
#   'oscillator',
#   'current',
#   'tunable',
#   'bifurcations'],
#  ['circuit',
#   'realization',
#   'lamb',
#   'ert',
#   'function',
#   'chaotic',
#   'circuit',
#   'figure',
#   'shows',
#   'new',
#   'circuit',
#   'realization',
#   'lambert',
#   'function',
#   'new',
#   'chaotic',
#   'circuit'],
#  ['circuit', 'consists', 'three', 'main', 'parts'],
#  ['th',
#   'first',
#   'part',
#   'employs',
#   'wilson',
#   'current',
#   'mirror',
#   'using',
#   'three',
#   'identical',
#   'transistors',
#   'current',
#   'source'],
#  ['second',
#   'part',
#   'simple',
#   'resistor',
#   'two',
#   'connected',
#   'emitters',
#   'negative',
#   'supply'],
#  ['parts',
#   'form',
#   'new',
#   'circuit',
#   'lambert',
#   'function',
#   'enabling',
#   'shown',
#   'later',
#   'exponential',
#   'equation',
#   'term',
#   'emitter',
#   'current',
#   'simultaneously',
#   'appear',
#   'sides',
#   'nonlinear',
#   'equation',
#   'appropriately',
#   'suitable',
#   'realization',
#   'lambert',
#   'function'],
#  ['third',
#   'part',
#   'consists',
#   'clc',
#   'network',
#   'using',
#   'two',
#   'capacitors',
#   'inductor',
#   'resistor',
#   'connected',
#   'wilson',
#   'current',
#   'mirror'],
#  ['third',
#   'part',
#   'links',
#   'nonlinear',
#   'circuit',
#   'lambert',
#   'function',
#   'developed',
#   'first',
#   'second',
#   'parts',
#   'chaotic',
#   'circuit'],
#  ['reference', 'fig'],
#  ['let',
#   'common',
#   'base',
#   'common',
#   'emitter',
#   'current',
#   'gains',
#   'tran',
#   'sistor',
#   'respectively',
#   'vbe',
#   'vbe',
#   'base',
#   'emitter',
#   'voltages',
#   'ie',
#   'ie',
#   'emitter',
#   'currents',
#   'respectively'],
# ...
#   'ecti',
#   'international',
#   'conference',
#   'mso',
#   'generated',
#   'frequency',
#   'high',
#   'mhz',
#   'according',
#   'theoretical'],
#  ['circuit',
#   'generate',
#   'frequency',
#   'higher',
#   'mhz',
#   'simulation',
#   'resu',
#   'lts',
#   'confirm',
#   'theory',
#   'error',
#   'cause',
#   'para',
#   'sitic',
#   'capacitor',
#   'ota'],
#  ['finally', 'fig'],
#  ['shows',
#   'output',
#   'currents',
#   'varied',
#   'bias',
#   'current',
#   'abc',
#   'pf',
#   'oscillation',
#   'frequency',
#   'mhz',
#   'simulated',
#   'theoretical',
#   'fig'],
#  ['variation',
#   'oscillation',
#   'frequency',
#   'capacitor',
#   'output',
#   'current',
#   'ap',
#   'bias',
#   'current',
#   'afig'],
#  ['output',
#   'currents',
#   'proposed',
#   'multiphase',
#   'sinu',
#   'soidal',
#   'oscillator',
#   'varying',
#   'bias',
#   'current',
#   'pf',
#   'pf'],
#  ['iv',
#   'onclusions',
#   'paper',
#   'new',
#   'electronically',
#   'tunable',
#   'mso',
#   'cir',
#   'cuit',
#   'presented'],
#  ['proposed',
#   'mso',
#   'circuit',
#   'simple',
#   'configuration',
#   'uses',
#   'multiple',
#   'output',
#   'ota',
#   'two',
#   'grounded',
#   'capacitors',
#   'per',
#   'section'],
#  ['mso',
#   'circuit',
#   'ca',
#   'configured',
#   'provide',
#   'odd',
#   'number',
#   'equal',
#   'amplit',
#   'ude',
#   'equally',
#   'special',
#   'phase',
#   'output',
#   'current'],
#  ['freque', 'ncy', 'condition', 'oscillation', 'independent', 'controlled'],
#  ['proposed',
#   'mso',
#   'enjoys',
#   'simple',
#   'structure',
#   'electronic',
#   'ally',
#   'tunable',
#   'suitable',
#   'ic',
#   'implementation',
#   'cmos',
#   'bipolar',
#   'technologies'],
#  ['simulation', 'results', 'confirm', 'theoretical', 'analysis', 'obtained'],
#  ['references',
#   'sanchez',
#   'sinecio',
#   'ramirez',
#   'angulo',
#   'linare',
#   'barranco',
#   'rodriguez',
#   'vazquez',
#   'operational',
#   'transconductance',
#   'plifier',
#   'based',
#   'non',
#   'linear',
#   'function',
#   'syntheses',
#   'ieee',
#   'journal',
#   'solid',
#   'state',
#   'circuits',
#   'vol'],
#  ['pp'],
#  ['rodriguez',
#   'vazquez',
#   'linares',
#   'barranco',
#   'hu',
#   'ertas',
#   'sanchez',
#   'sinencio',
#   'design',
#   'voltage',
#   'controll',
#   'ed',
#   'sinusoidal',
#   'oscillators',
#   'using',
#   'ota',
#   'ieee',
#   'transactions',
#   'circuits',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['khan',
#   'ahmed',
#   'minhaj',
#   'tunable',
#   'ota',
#   'based',
#   'multiphase',
#   'sinusoidal',
#   'oscillators',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['wu',
#   'current',
#   'mode',
#   'high',
#   'order',
#   'ota',
#   'filters',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['tsukutani',
#   'ishida',
#   'tsuiki',
#   'kukui',
#   'versatile',
#   'current',
#   'mode',
#   'biquad',
#   'filter',
#   'using',
#   'multiple',
#   'current',
#   'output',
#   'ot',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['sun',
#   'fidler',
#   'structure',
#   'generation',
#   'nd',
#   'design',
#   'multiple',
#   'loop',
#   'feedback',
#   'ota',
#   'grounded',
#   'capacitor',
#   'filter',
#   'ieee',
#   'transaction',
#   'circuits',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['prommee',
#   'dejhan',
#   'integrable',
#   'electro',
#   'nic',
#   'controlled',
#   'quadrature',
#   'sinusoidal',
#   'oscillator',
#   'using',
#   'cmos',
#   'operati',
#   'onal',
#   'transconductance',
#   'amplifier',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['kaplan',
#   'bachar',
#   'versatile',
#   'volt',
#   'age',
#   'controlled',
#   'three',
#   'phase',
#   'oscillator',
#   'ieee',
#   'transaction',
#   'industrial',
#   'electronics',
#   'control',
#   'instrumentation',
#   'vol'],
#  ['pp'],
#  ['rahman',
#   'haque',
#   'simple',
#   'three',
#   'phase',
#   'variable',
#   'frequency',
#   'oscillation',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['ramamurti',
#   'ramaswami',
#   'novel',
#   'thre',
#   'phase',
#   'reference',
#   'sinewave',
#   'generator',
#   'pwm',
#   'inverter',
#   'ieee',
#   'transactions',
#   'industrial',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['mikhael',
#   'tu',
#   'continuous',
#   'switch',
#   'ed',
#   'capacitor',
#   'multiphase',
#   'oscillators',
#   'ieee',
#   'transactions',
#   'circuits',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['hou',
#   'shen',
#   'second',
#   'generation',
#   'current',
#   'conveyor',
#   'based',
#   'multiphase',
#   'sinusoidal',
#   'oscillators',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['wu'],
#  ['liu'],
#  ['hwang'],
#  ['wu',
#   'multiphase',
#   'sinusoidal',
#   'oscillator',
#   'using',
#   'second',
#   'generation',
#   'curre',
#   'nt',
#   'conveyors',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['wu'],
#  ['liu'],
#  ['hwang'],
#  ['wu',
#   'mul',
#   'tiphase',
#   'sinusoidal',
#   'oscillator',
#   'using',
#   'cfoa',
#   'pole',
#   'iee',
#   'proceeding',
#   'circuits',
#   'devices',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['gift',
#   'multiphase',
#   'sinusoidal',
#   'oscillato',
#   'system',
#   'using',
#   'operational',
#   'amplifiers',
#   'international',
#   'journal',
#   'electronics',
#   'vol'],
#  ['pp'],
#  ['gift',
#   'multiphase',
#   'sinusoidal',
#   'oscillato',
#   'using',
#   'inverting',
#   'mode',
#   'operational',
#   'amplifiers',
#   'ieee',
#   'transactions',
#   'instrumentation',
#   'measurement',
#   'vol'],
#  ['pp'],
#  ['abuelma',
#   'atti',
#   'al',
#   'qahani',
#   'new',
#   'current',
#   'controlled',
#   'multiphase',
#   'sinusoidal',
#   'oscillator',
#   'using',
#   'ranslinear',
#   'current',
#   'conveyor',
#   'ieee',
#   'transactions',
#   'circuits',
#   'systems',
#   'ii',
#   'analo',
#   'digital',
#   'signal',
#   'processing',
#   'vol'],
#  ['pp'],
#  ['bhusan'],
#  ['newcomb',
#   'grounding',
#   'capac',
#   'itors',
#   'integrated',
#   'circuits',
#   'electronics',
#   'letters',
#   'vol'],
#  ['pp'],
#  ['tan',
#   'schaumann',
#   'simulation',
#   'general',
#   'lc',
#   'ladder',
#   'filters',
#   'monolithic',
#   'realizations',
#   'transconducta',
#   'nce',
#   'elements',
#   'grounded',
#   'capacitors',
#   'ieee',
#   'transaction',
#   'circuits',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['szczepanski',
#   'wyazynski',
#   'schaumann',
#   'high',
#   'linear',
#   'voltage',
#   'controlled',
#   'cmos',
#   'transconductances',
#   'ieee',
#   'transaction',
#   'circuits',
#   'systems',
#   'vol'],
#  ['pp'],
#  ['ecti', 'con', 'ecti', 'international', 'conference'],
#  ['compound',
#   'structures',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'based',
#   'sinh',
#   'nonlinearity',
#   'banlue',
#   'srisuchinwong',
#   'teerachot',
#   'siriburanon',
#   'teera',
#   'nontapradit',
#   'sirindhorn',
#   'international',
#   'institute',
#   'technology',
#   'thammasat',
#   'university',
#   'pathum',
#   'thani',
#   'thailand',
#   'email',
#   'banlue',
#   'siit',
#   'tu',
#   'ac',
#   'th',
#   'abstract',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'presented',
#   'based',
#   'six',
#   'new',
#   'sets',
#   'single',
#   'coefficient',
#   'hyperbolic',
#   'arcsine',
#   'nonlinearity'],
#  ['particular',
#   'compound',
#   'st',
#   'ructures',
#   'chaotic',
#   'attractors',
#   'demonstrated',
#   'use',
#   'half',
#   'mage',
#   'operation',
#   'using',
#   'control',
#   'parameter',
#   'positive',
#   'value',
#   'appropriate',
#   'isolates',
#   'right',
#   'half',
#   'image',
#   'attractors',
#   'whilst',
#   'negative',
#   'value',
#   'appropriate',
#   'isolates',
#   'left',
#   'half',
#   'image',
#   'attractor'],
#  ['images', 'merged', 'ogether', 'compound', 'structure'],
#  ['keywords',
#   'chaos',
#   'jerk',
#   'model',
#   'compund',
#   'st',
#   'ructure',
#   'single',
#   'coefficient',
#   'hyperbolic',
#   'arcsin',
#   'nonlinearity'],
#  ['introduction',
#   'well',
#   'known',
#   'chua',
#   'chaotic',
#   'oscillator',
#   'based',
#   'three',
#   'first',
#   'order',
#   'differential',
#   'equations',
#   'odes'],
#  ['contrast',
#   'sprott',
#   'alternatively',
#   'proposed',
#   'chaotic',
#   'oscillators',
#   'based',
#   'single',
#   'third',
#   'order',
#   'ode',
#   'jerk',
#   'model',
#   'single',
#   'coefficient',
#   'form',
#   'term',
#   'jerk',
#   'comes',
#   'fact',
#   'mechan',
#   'ical',
#   'system',
#   'displacement',
#   'successive',
#   'time',
#   'derivatives',
#   'velocity',
#   'acceleration',
#   'jerk'],
#  ['nonlin',
#   'ear',
#   'component',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'suggested',
#   'follows',
#   'max',
#   'sgn',
#   'sgn',
#   'sin',
#   'tan',
#   'tanh',
#   'sgn',
#   'kxkxkxxkxxgxtanhxxk',
#   'xxk',
#   'kxxkxxkxx',
#   'dxdxdx',
#   'kgxdtdtdt',
#   'srisuchinwong',
#   'siriburanon',
#   'nontapradit',
#   'jerk',
#   'models',
#   'implemented',
#   'using',
#   'current',
#   'feedback',
#   'op',
#   'amps'],
#  ['addition',
#   'new',
#   'sets',
#   'single',
#   'coefficient',
#   'presented',
#   'based',
#   'new',
#   'sets',
#   'either',
#   'tan',
#   'nonlinearity',
#   'sin',
#   'nonlinearity'],
#  ['recently',
#   'compound',
#   'structures',
#   'chaotic',
#   'attractors',
#   'based',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'compound',
#   'structures',
#   'others',
#   'proposed'],
#  ['paper',
#   'six',
#   'new',
#   'chaotic',
#   'attractor',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'presented',
#   'using',
#   'six',
#   'ne',
#   'sets',
#   'single',
#   'coefficient',
#   'hyperbolic',
#   'arcsine',
#   'nonlinearity'],
#  ['ddition',
#   'compound',
#   'structures',
#   'chaotic',
#   'attractor',
#   'also',
#   'demonstrated'],
#  ['modified', 'single', 'coefficient', 'jerk', 'model'],
#  ['six',
#   'new',
#   'sets',
#   'coefficients',
#   'nonlienarity',
#   'figure',
#   'shows',
#   'structural',
#   'implementation',
#   'jerk',
#   'model',
#   'described',
#   'single',
#   'coefficient',
#   'nonlinearity',
#   'modified'],
#  ['varying',
#   'coefficient',
#   'nonlinear',
#   'component',
#   'computer',
#   'simulations',
#   'six',
#   'new',
#   'sets',
#   'coefficient',
#   'new',
#   'nonlinearity',
#   'base',
#   'hyperbolic',
#   'arcsine',
#   'functions',
#   'proposed',
#   'follows',
#   'figure'],
#  ['single', 'coefficient', 'jerk', 'model'],
#  ['gxsinhxxk',
#   'gxsinhxxk',
#   'gxsinhxxk',
#   'gxgxsinhxxk',
#   'gxsinhxxk',
#   'gxsinhxxk',
#   'compound',
#   'structures',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'based',
#   'sinh',
#   'nonlinearity'],
#  ['compound',
#   'structures',
#   'new',
#   'chaotic',
#   'attractors',
#   'new',
#   'systems',
#   'compound',
#   'structures',
#   'may',
#   'demonstrated',
#   'using',
#   'half',
#   'image',
#   'operation',
#   'obtain',
#   'left',
#   'right',
#   'half',
#   'image',
#   'attractors',
#   'merged',
#   'together',
#   'compound',
#   'structure'],
#  ['operation',
#   'revealed',
#   'use',
#   'controlled',
#   'system',
#   'form',
#   'control',
#   'parameter'],
#  ['negative',
#   'value',
#   'appropriate',
#   'results',
#   'isolation',
#   'left',
#   'half',
#   'image',
#   'original',
#   'attractor'],
#  ['contrary',
#   'positive',
#   'value',
#   'appropriate',
#   'results',
#   'isolation',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor'],
#  ['numerical', 'results'],
#  ['new',
#   'chaotic',
#   'attractors',
#   'using',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'described',
#   'six',
#   'new',
#   'sets',
#   'described',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'displayed',
#   'respectively',
#   'figs'],
#  ['phase', 'plane', 'figs'],
#  ['phase', 'plane'],
#  ['appears',
#   'new',
#   'attractors',
#   'exhibit',
#   'complex',
#   'behaviors',
#   'chaotic',
#   'dynamics'],
#  ['compound',
#   'structures',
#   'new',
#   'chaotic',
#   'attractors',
#   'nonlinearity',
#   'left',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'see',
#   'fig'],
#  ['isolated', 'illustrated', 'figs'],
#  ['contrast',
#   'another',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'isolated',
#   'illustrated',
#   'figs'],
#  ['nonlinearity',
#   'left',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'see',
#   'fig'],
#  ['isolated', 'illustrated', 'figs'],
#  ['contrast',
#   'another',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'isolated',
#   'illu',
#   'strated',
#   'figs'],
#  ['nonlinearity',
#   'left',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'see',
#   'fig'],
#  ['isolated', 'illustrated', 'figs'],
#  ['contrast',
#   'another',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'isolated',
#   'illu',
#   'strated',
#   'figs'],
#  ['nonlinearity',
#   'left',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'see',
#   'fig'],
#  ['isolated', 'illustrated', 'figs'],
#  ['contrast',
#   'another',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'isolated',
#   'illustrated',
#   'figs'],
#  ['dxdxdx',
#   'kgxn',
#   'dtdtdt',
#   'srisuchinwong',
#   'siriburanon',
#   'nontapradit',
#   'nonlinearity',
#   'left',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'see',
#   'fig'],
#  ['isolated', 'illustrated', 'figs'],
#  ['contrast',
#   'another',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'isolated',
#   'illustrated',
#   'figs'],
#  ['finally',
#   'nonlinearity',
#   'left',
#   'alf',
#   'image',
#   'original',
#   'attractor',
#   'see',
#   'fig'],
#  ['isolated', 'illustrated', 'figs'],
#  ['contrast',
#   'another',
#   'right',
#   'half',
#   'image',
#   'original',
#   'attractor',
#   'isolated',
#   'illustrated',
#   'figs'],
#  ['new',
#   'original',
#   'attractors',
#   'left',
#   'half',
#   'image',
#   'attractors',
#   'right',
#   'half',
#   'image',
#   'attractors',
#   'sinh',
#   'sinh',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'figure'],
#  ['six',
#   'new',
#   'chaotic',
#   'attractors',
#   'compound',
#   'structures',
#   'isolated',
#   'le',
#   'ft',
#   'right',
#   'half',
#   'image',
#   'attractors'],
#  ['compound',
#   'structures',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'based',
#   'sinh',
#   'nonlinearity',
#   'sinh',
#   'sinh',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'figure'],
#  ['six',
#   'new',
#   'chaotic',
#   'attractors',
#   'compound',
#   'structures',
#   'isolated',
#   'left',
#   'ri',
#   'ght',
#   'half',
#   'image',
#   'attractors',
#   'continued'],
#  ['srisuchinwong', 'siriburanon', 'nontapradit', 'sinh', 'sinh'],
#  ['conclusions',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'proposed',
#   'using',
#   'six',
#   'new',
#   'sets',
#   'single',
#   'coefficients',
#   'hyperbolic',
#   'arcsine',
#   'nonlinear',
#   'function'],
#  ['addition',
#   'compound',
#   'structures',
#   'six',
#   'chaotic',
#   'attractors',
#   'demonstrated',
#   'using',
#   'half',
#   'image',
#   'operation',
#   'obtain',
#   'left',
#   'right',
#   'half',
#   'image',
#   'attractors',
#   'merged',
#   'together',
#   'compound',
#   'structure'],
#  ['axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'axis',
#   'figure'],
#  ['six',
#   'new',
#   'chaotic',
#   'attractors',
#   'compound',
#   'structures',
#   'isolated',
#   'left',
#   'right',
#   'half',
#   'image',
#   'attractors',
#   'continued'],
#  ['compound',
#   'structures',
#   'six',
#   'new',
#   'chaotic',
#   'attractors',
#   'modified',
#   'single',
#   'coefficient',
#   'jerk',
#   'model',
#   'based',
#   'sinh',
#   'nonlinearity',
#   'references',
#   'matsumoto',
#   'chaotic',
#   'attractor',
#   'hua',
#   'circuit',
#   'ieee',
#   'trans'],
#  ['circuits', 'systems', 'vol'],
#  ['cas'],
#  ['srisuchinwong',
#   'san',
#   'um',
#   'chua',
#   'chaotic',
#   'oscillator',
#   'based',
#   'coarsely',
#   'cubi',
#   'like',
#   'cmos',
#   'resistor',
#   'proceedings',
#   'asia',
#   'pac',
#   'ific',
#   'conference',
#   'communications',
#   'apcc'],
#  ['sprott',
#   'new',
#   'cl',
#   'ass',
#   'chaotic',
#   'circuit',
#   'physics',
#   'letters',
#   'vol'],
#  ['schot', 'time', 'rate', 'change', 'acceleration'],
#  ['phys', 'vol'],
#  ['sprott', 'simple', 'chaotic', 'systems', 'circuits'],
#  ['phys'],
#  ['sprott',
#   'simplifications',
#   'lorenz',
#   'attractor',
#   'nonlinear',
#   'dynamics',
#   'psychology',
#   'life',
#   'sciences'],
#  ['srisuchinwong'],
#  ...]

# %%
# Import the built-in logging module and configure it so that Word2Vec 
# creates nice output messages
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# Set values for various parameters
num_features = 500    # Word vector dimensionality                      
min_word_count = 0  # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(split_sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# 2017-05-22 18:18:19,900 : INFO : 'pattern' package not found; tag filters are not available for English
# 2017-05-22 18:18:19,961 : INFO : collecting all words and their counts
# 2017-05-22 18:18:19,962 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-05-22 18:18:20,005 : INFO : PROGRESS: at sentence #10000, processed 130042 words, keeping 40812 word types
# 2017-05-22 18:18:20,048 : INFO : PROGRESS: at sentence #20000, processed 251062 words, keeping 75681 word types
# 2017-05-22 18:18:20,104 : INFO : PROGRESS: at sentence #30000, processed 374115 words, keeping 116445 word types
# 2017-05-22 18:18:20,150 : INFO : PROGRESS: at sentence #40000, processed 481567 words, keeping 149626 word types
# Training model...
# 2017-05-22 18:18:20,196 : INFO : PROGRESS: at sentence #50000, processed 607326 words, keeping 174323 word types
# 2017-05-22 18:18:20,240 : INFO : PROGRESS: at sentence #60000, processed 698940 words, keeping 192433 word types
# 2017-05-22 18:18:20,279 : INFO : PROGRESS: at sentence #70000, processed 799841 words, keeping 218492 word types
# 2017-05-22 18:18:20,326 : INFO : PROGRESS: at sentence #80000, processed 937921 words, keeping 255256 word types
# 2017-05-22 18:18:20,374 : INFO : PROGRESS: at sentence #90000, processed 1076299 words, keeping 286888 word types
# 2017-05-22 18:18:20,417 : INFO : PROGRESS: at sentence #100000, processed 1196341 words, keeping 309466 word types
# 2017-05-22 18:18:20,457 : INFO : PROGRESS: at sentence #110000, processed 1322981 words, keeping 317892 word types
# 2017-05-22 18:18:20,502 : INFO : PROGRESS: at sentence #120000, processed 1456107 words, keeping 347669 word types
# 2017-05-22 18:18:20,571 : INFO : PROGRESS: at sentence #130000, processed 1574363 words, keeping 372299 word types
# 2017-05-22 18:18:20,622 : INFO : PROGRESS: at sentence #140000, processed 1710161 words, keeping 391537 word types
# 2017-05-22 18:18:20,671 : INFO : PROGRESS: at sentence #150000, processed 1847335 words, keeping 413048 word types
# 2017-05-22 18:18:20,711 : INFO : PROGRESS: at sentence #160000, processed 1973345 words, keeping 418941 word types
# 2017-05-22 18:18:20,755 : INFO : PROGRESS: at sentence #170000, processed 2098910 words, keeping 419382 word types
# 2017-05-22 18:18:20,795 : INFO : PROGRESS: at sentence #180000, processed 2225762 words, keeping 420600 word types
# 2017-05-22 18:18:20,838 : INFO : PROGRESS: at sentence #190000, processed 2355818 words, keeping 430164 word types
# 2017-05-22 18:18:20,883 : INFO : collected 440471 word types from a corpus of 2479558 raw words and 199336 sentences
# 2017-05-22 18:18:20,884 : INFO : Loading a fresh vocabulary
# 2017-05-22 18:18:23,019 : INFO : min_count=0 retains 440471 unique words (100% of original 440471, drops 0)
# 2017-05-22 18:18:23,020 : INFO : min_count=0 leaves 2479558 word corpus (100% of original 2479558, drops 0)
# 2017-05-22 18:18:24,488 : INFO : deleting the raw counts dictionary of 440471 items
# 2017-05-22 18:18:24,509 : INFO : sample=0.001 downsamples 5 most-common words
# 2017-05-22 18:18:24,511 : INFO : downsampling leaves estimated 2476634 word corpus (99.9% of prior 2479558)
# 2017-05-22 18:18:24,513 : INFO : estimated required memory for 440471 words and 500 dimensions: 1982119500 bytes
# 2017-05-22 18:18:26,284 : INFO : resetting layer weights
# 2017-05-22 18:18:35,004 : INFO : training model with 4 workers on 440471 vocabulary and 500 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-05-22 18:18:35,005 : INFO : expecting 199336 sentences, matching count from corpus used for vocabulary survey
# 2017-05-22 18:18:36,065 : INFO : PROGRESS: at 1.61% examples, 194869 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:37,067 : INFO : PROGRESS: at 3.25% examples, 192138 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:38,092 : INFO : PROGRESS: at 4.88% examples, 192951 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:39,193 : INFO : PROGRESS: at 7.08% examples, 194433 words/s, in_qsize 6, out_qsize 1
# 2017-05-22 18:18:40,232 : INFO : PROGRESS: at 8.46% examples, 191995 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:41,251 : INFO : PROGRESS: at 10.30% examples, 197445 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:42,272 : INFO : PROGRESS: at 12.19% examples, 203873 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:43,287 : INFO : PROGRESS: at 14.14% examples, 209008 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:44,315 : INFO : PROGRESS: at 16.31% examples, 215924 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:45,350 : INFO : PROGRESS: at 18.28% examples, 218433 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:46,361 : INFO : PROGRESS: at 20.04% examples, 219197 words/s, in_qsize 6, out_qsize 2
# 2017-05-22 18:18:47,381 : INFO : PROGRESS: at 21.96% examples, 220462 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:48,414 : INFO : PROGRESS: at 24.47% examples, 225066 words/s, in_qsize 6, out_qsize 1
# 2017-05-22 18:18:49,445 : INFO : PROGRESS: at 27.17% examples, 229029 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:50,480 : INFO : PROGRESS: at 29.33% examples, 232412 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:51,518 : INFO : PROGRESS: at 31.64% examples, 235313 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:52,524 : INFO : PROGRESS: at 33.70% examples, 236613 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:18:53,558 : INFO : PROGRESS: at 35.57% examples, 236861 words/s, in_qsize 6, out_qsize 1
# 2017-05-22 18:18:54,558 : INFO : PROGRESS: at 37.49% examples, 236994 words/s, in_qsize 8, out_qsize 1
# 2017-05-22 18:18:55,657 : INFO : PROGRESS: at 39.88% examples, 239369 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:56,705 : INFO : PROGRESS: at 41.79% examples, 238817 words/s, in_qsize 6, out_qsize 1
# 2017-05-22 18:18:57,730 : INFO : PROGRESS: at 43.71% examples, 237694 words/s, in_qsize 6, out_qsize 1
# 2017-05-22 18:18:58,748 : INFO : PROGRESS: at 45.66% examples, 237527 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:18:59,763 : INFO : PROGRESS: at 48.03% examples, 238253 words/s, in_qsize 8, out_qsize 1
# 2017-05-22 18:19:00,813 : INFO : PROGRESS: at 50.12% examples, 238999 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:01,823 : INFO : PROGRESS: at 52.26% examples, 240369 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:02,927 : INFO : PROGRESS: at 54.56% examples, 241577 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:03,967 : INFO : PROGRESS: at 56.62% examples, 241845 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:04,991 : INFO : PROGRESS: at 58.60% examples, 241905 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:06,015 : INFO : PROGRESS: at 60.46% examples, 241949 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:07,017 : INFO : PROGRESS: at 62.61% examples, 242479 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:08,029 : INFO : PROGRESS: at 64.98% examples, 243511 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:09,072 : INFO : PROGRESS: at 67.57% examples, 244247 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:10,141 : INFO : PROGRESS: at 69.57% examples, 244190 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:11,193 : INFO : PROGRESS: at 71.50% examples, 243707 words/s, in_qsize 6, out_qsize 1
# 2017-05-22 18:19:12,231 : INFO : PROGRESS: at 73.25% examples, 242811 words/s, in_qsize 7, out_qsize 1
# 2017-05-22 18:19:13,239 : INFO : PROGRESS: at 74.91% examples, 242401 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:14,245 : INFO : PROGRESS: at 76.76% examples, 242034 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:15,312 : INFO : PROGRESS: at 78.48% examples, 241078 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:16,346 : INFO : PROGRESS: at 80.26% examples, 240598 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:17,429 : INFO : PROGRESS: at 81.94% examples, 239387 words/s, in_qsize 7, out_qsize 1
# 2017-05-22 18:19:18,456 : INFO : PROGRESS: at 84.08% examples, 239464 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:19,487 : INFO : PROGRESS: at 86.58% examples, 239483 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:20,522 : INFO : PROGRESS: at 88.39% examples, 239508 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:21,538 : INFO : PROGRESS: at 90.30% examples, 239427 words/s, in_qsize 8, out_qsize 0
# 2017-05-22 18:19:22,564 : INFO : PROGRESS: at 92.19% examples, 239482 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:23,582 : INFO : PROGRESS: at 94.32% examples, 240209 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:24,594 : INFO : PROGRESS: at 96.31% examples, 240332 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:25,634 : INFO : PROGRESS: at 98.13% examples, 239921 words/s, in_qsize 7, out_qsize 0
# 2017-05-22 18:19:26,510 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-05-22 18:19:26,536 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-05-22 18:19:26,574 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-05-22 18:19:26,622 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-05-22 18:19:26,624 : INFO : training on 12397790 raw words (12383091 effective words) took 51.6s, 240067 effective words/s

# %%
len(model.wv.vocab)
# Out:
# 440471

# %%
model.most_similar('resistance')
# Out:
# 2017-05-22 18:19:26,709 : INFO : precomputing L2-norms of word weight vectors
# [('hydrogel', 0.9876585006713867),
#  ('triggered', 0.9848117232322693),
#  ('strengths', 0.9845622181892395),
#  ('molecular', 0.9845357537269592),
#  ('variations', 0.9835673570632935),
#  ('phenomenon', 0.9830471277236938),
#  ('sensitive', 0.982763946056366),
#  ('strength', 0.9811860918998718),
#  ('gains', 0.9810322523117065),
#  ('causes', 0.9809278845787048)]

# %%
model.most_similar('database')
# Out:
# [('directory', 0.9709730744361877),
#  ('server', 0.9668992161750793),
#  ('wikipedia', 0.9631386995315552),
#  ('files', 0.9602453112602234),
#  ('unl', 0.9600975513458252),
#  ('orchid', 0.9591746926307678),
#  ('statistics', 0.9544699192047119),
#  ('gateway', 0.9543536901473999),
#  ('wordnet', 0.9538884162902832),
#  ('client', 0.9532955288887024)]

# %%
model.most_similar('corpus')
# Out:
# [('statistics', 0.9816146492958069),
#  ('grammars', 0.9611673951148987),
#  ('texts', 0.9579599499702454),
#  ('annotating', 0.9571319222450256),
#  ('extracting', 0.9557010531425476),
#  ('transcription', 0.9544445276260376),
#  ('designexperimental', 0.9539710879325867),
#  ('text', 0.9529205560684204),
#  ('dictionary', 0.9528775215148926),
#  ('lexical', 0.9521612524986267)]

# %%
model.most_similar('create')
# Out:
# [('allows', 0.9830431938171387),
#  ('put', 0.9830320477485657),
#  ('build', 0.9803174734115601),
#  ('acquire', 0.9784332513809204),
#  ('created', 0.9778603315353394),
#  ('generate', 0.9776138067245483),
#  ('allow', 0.9774624705314636),
#  ('execute', 0.9767727851867676),
#  ('core', 0.9726788401603699),
#  ('appropriate', 0.9724059104919434)]

# %%
model.most_similar('electric')
# Out:
# [('muscle', 0.9701358079910278),
#  ('field', 0.9695734977722168),
#  ('hpci', 0.9680004119873047),
#  ('loads', 0.9668121337890625),
#  ('reducing', 0.9661319255828857),
#  ('failure', 0.9651815295219421),
#  ('cooling', 0.9617865085601807),
#  ('calories', 0.9594910144805908),
#  ('change', 0.9591827988624573),
#  ('losses', 0.9588176608085632)]

# %%
model.most_similar('semantic')
# Out:
# [('named', 0.9711902141571045),
#  ('keywords', 0.9691453576087952),
#  ('extracting', 0.967287003993988),
#  ('linguistic', 0.9652711749076843),
#  ('srqvru', 0.9630720615386963),
#  ('lexical', 0.9619459509849548),
#  ('text', 0.9588766694068909),
#  ('thesaurus', 0.9582123756408691),
#  ('infor', 0.9573590159416199),
#  ('sentiment', 0.954674482345581)]

# %%
model.most_similar('key')
# Out:
# [('includes', 0.9771648049354553),
#  ('captures', 0.9771592020988464),
#  ('another', 0.9768005609512329),
#  ('accommodate', 0.9767913818359375),
#  ('ask', 0.9767223596572876),
#  ('already', 0.976711630821228),
#  ('handled', 0.9750445485115051),
#  ('particular', 0.9750428795814514),
#  ('serve', 0.9750289916992188),
#  ('involved', 0.9748645424842834)]

# %%
model.most_similar('test')
# Out:
# [('analyzed', 0.9652294516563416),
#  ('tests', 0.9629669189453125),
#  ('performed', 0.9562002420425415),
#  ('comparison', 0.9543420672416687),
#  ('comparisons', 0.9533629417419434),
#  ('validation', 0.9505937099456787),
#  ('obtained', 0.9471129775047302),
#  ('experiments', 0.9451783299446106),
#  ('scores', 0.9451711177825928),
#  ('rotary', 0.9447579979896545)]
